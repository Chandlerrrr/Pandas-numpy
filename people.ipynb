# %%
import pandas as pd
import numpy as np

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'], 
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)
df.replace("NA" , np.nan, inplace = True)
df.replace("Missing" , np.nan, inplace = True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.apply(len)
# Out:
# first    7
# last     7
# email    7
# age      7
# dtype: int64

# %%
df.applymap(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-d38ddfc50172> in <module>
# ----> 1 df.applymap(len)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in applymap(self, func)
#    6551             return lib.map_infer(x.astype(object).values, func)
#    6552
# -> 6553         return self.apply(infer)
#    6554
#    6555     # ----------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# ...

# %%
df['full name']=df['first'] + ' ' + df['last']

# %%
df
# Out:
#    first     last                    email   age      full name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com    55       Jane Doe
# 2   John      Doe        JohnDoe@email.com    63       John Doe
# 3  Chris  Schafer                     None    36  Chris Schafer
# 4    NaN      NaN                      NaN  None            NaN
# 5   None      NaN      Anonymous@email.com  None            NaN
# 6    NaN      NaN                      NaN   NaN            NaN

# %%
df.drop(columns = ['fullname'] , inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-34c02187e95f> in <module>
# ----> 1 df.drop(columns = ['fullname'] , inplace = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df
# Out:
#    first     last                    email   age      full name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com    55       Jane Doe
# 2   John      Doe        JohnDoe@email.com    63       John Doe
# 3  Chris  Schafer                     None    36  Chris Schafer
# 4    NaN      NaN                      NaN  None            NaN
# 5   None      NaN      Anonymous@email.com  None            NaN
# 6    NaN      NaN                      NaN   NaN            NaN

# %%
df.drop(columns=['first' , 'last'] , inplace = True)

# %%
df
# Out:
#                      email      full name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
df[['first' , 'last']] = df['full name'].str.split(' ', expand = True)

# %%
df
# Out:
#                      email      full name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
df.append({'first' : 'tony'} , ignore_index =True)
# Out:
#                      email      full name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN   tony      NaN

# %%
people = {
    'first': ['Tony', 'Steve' , 'Chandler'], 
    'last': ['Stark', 'Rogers','bingaling'], 
    'email': ['Ironmaninc@gmail.com', 'capamerica@avenge.com' , 'chandlerbing@penus.com']
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#       first       last                   email
# 0      Tony      Stark    Ironmaninc@gmail.com
# 1     Steve     Rogers   capamerica@avenge.com
# 2  Chandler  bingaling  chandlerbing@penus.com

# %%
df = df.append(df2 , ignore_index  = True  ,sort= False)

# %%
df
# Out:
#       first       last                   email
# 0      Tony      Stark    Ironmaninc@gmail.com
# 1     Steve     Rogers   capamerica@avenge.com
# 2  Chandler  bingaling  chandlerbing@penus.com
# 3      Tony      Stark    Ironmaninc@gmail.com
# 4     Steve     Rogers   capamerica@avenge.com
# 5  Chandler  bingaling  chandlerbing@penus.com

# %%
df
# Out:
#       first       last                   email
# 0      Tony      Stark    Ironmaninc@gmail.com
# 1     Steve     Rogers   capamerica@avenge.com
# 2  Chandler  bingaling  chandlerbing@penus.com
# 3      Tony      Stark    Ironmaninc@gmail.com
# 4     Steve     Rogers   capamerica@avenge.com
# 5  Chandler  bingaling  chandlerbing@penus.com

# %%
df.drop([5])
# Out:
#       first       last                   email
# 0      Tony      Stark    Ironmaninc@gmail.com
# 1     Steve     Rogers   capamerica@avenge.com
# 2  Chandler  bingaling  chandlerbing@penus.com
# 3      Tony      Stark    Ironmaninc@gmail.com
# 4     Steve     Rogers   capamerica@avenge.com

# %%
df
# Out:
#       first       last                   email
# 0      Tony      Stark    Ironmaninc@gmail.com
# 1     Steve     Rogers   capamerica@avenge.com
# 2  Chandler  bingaling  chandlerbing@penus.com
# 3      Tony      Stark    Ironmaninc@gmail.com
# 4     Steve     Rogers   capamerica@avenge.com
# 5  Chandler  bingaling  chandlerbing@penus.com

# %%
df.drop(df.index[5] , inplace = True)

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.sort_values(by='last', ascending=False)
# Out:
#       first       last                   email
# 2  Chandler  bingaling  chandlerbing@penus.com
# 0      Tony      Stark    Ironmaninc@gmail.com
# 3      Tony      Stark    Ironmaninc@gmail.com
# 1     Steve     Rogers   capamerica@avenge.com
# 4     Steve     Rogers   capamerica@avenge.com

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
df
# Out:
#       first       last                   email
# 2  Chandler  bingaling  chandlerbing@penus.com
# 0      Tony      Stark    Ironmaninc@gmail.com
# 3      Tony      Stark    Ironmaninc@gmail.com
# 1     Steve     Rogers   capamerica@avenge.com
# 4     Steve     Rogers   capamerica@avenge.com

# %%
df.apply(len)
# Out:
# first    7
# last     7
# email    7
# age      7
# dtype: int64

# %%
df
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@email.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dropna(axis = "index", how = "all", subset = ["email" , 'last'])
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@email.com    55
# 2   John      Doe        JohnDoe@email.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@email.com  None

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@email.com       55
# 2     John      Doe        JohnDoe@email.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 0 to 6
# Data columns (total 4 columns):
# first    4 non-null object
# last     4 non-null object
# email    3 non-null object
# age      4 non-null object
# dtypes: object(4)
# memory usage: 240.0+ bytes

# %%
df.applymap(lambda x: len(str(x)))
# Out:
#    first  last  email  age  full name
# 0      5     7     23    2         13
# 1      4     3     17    2          8
# 2      4     3     17    2          8
# 3      5     7      4    2         13
# 4      3     3      3    4          3
# 5      4     3     19    4          3
# 6      3     3      3    3          3

# %%
df
# Out:
#    first     last                    email   age      full name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com    55       Jane Doe
# 2   John      Doe        JohnDoe@email.com    63       John Doe
# 3  Chris  Schafer                     None    36  Chris Schafer
# 4    NaN      NaN                      NaN  None            NaN
# 5   None      NaN      Anonymous@email.com  None            NaN
# 6    NaN      NaN                      NaN   NaN            NaN

# %%
df.dtypes
# Out:
# first        object
# last         object
# email        object
# age          object
# full name    object
# dtype: object

# %%
df['age'] = df['age'].astype(float)

# %%
df.dtypes
# Out:
# first         object
# last          object
# email         object
# age          float64
# full name     object
# dtype: object

# %%
df['age'].mean()
# Out:
# 46.75
