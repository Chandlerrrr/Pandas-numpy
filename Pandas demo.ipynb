# %%
import pandas as pd

# %%
na_vals = ['NA' , 'Missing']
df = pd.read_csv("data\survey_results_public.csv" , index_col = 'Respondent' , na_values = na_vals)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.shape
# Out:
# (64461, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
# Respondent                      64461 non-null int64
# MainBranch                      64162 non-null object
# Hobbyist                        64416 non-null object
# Age                             45446 non-null float64
# Age1stCode                      57900 non-null object
# CompFreq                        40069 non-null object
# CompTotal                       34826 non-null float64
# ConvertedComp                   34756 non-null float64
# Country                         64072 non-null object
# CurrencyDesc                    45472 non-null object
# CurrencySymbol                  45472 non-null object
# DatabaseDesireNextYear          44070 non-null object
# DatabaseWorkedWith              49537 non-null object
# DevType                         49370 non-null object
# EdLevel                         57431 non-null object
# ...

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows',61)

# %%
df.head(100)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1                     I am a developer by profession      Yes
# 1            2                     I am a developer by profession       No
# 2            3                        I code primarily as a hobby      Yes
# 3            4                     I am a developer by profession      Yes
# 4            5  I used to be a developer by profession, but no...      Yes
# 5            6                     I am a developer by profession       No
# 6            7                     I am a developer by profession      Yes
# 7            8                     I am a developer by profession      Yes
# 8            9                     I am a developer by profession       No
# 9           10                     I am a developer by profession      Yes
# 10          11                     I am a developer by profession      Yes
# ...

# %%
df.head(-2)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# 5               6                     I am a developer by profession       No
# 6               7                     I am a developer by profession      Yes
# 7               8                     I am a developer by profession      Yes
# 8               9                     I am a developer by profession       No
# 9              10                     I am a developer by profession      Yes
# 10             11                     I am a developer by profession      Yes
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  Age Age1stCode CompFreq  CompTotal  \
# 64451       64104        NaN      Yes  NaN         19      NaN        NaN
# 64452       64236        NaN      Yes  NaN        NaN      NaN        NaN
# 64453       64330        NaN      Yes  NaN          5      NaN        NaN
# 64454       64480        NaN      Yes  NaN         21      NaN        NaN
# 64455       64567        NaN      Yes  NaN        NaN      NaN        NaN
# 64456       64858        NaN      Yes  NaN         16      NaN        NaN
# 64457       64867        NaN      Yes  NaN        NaN      NaN        NaN
# 64458       64898        NaN      Yes  NaN        NaN      NaN        NaN
# 64459       64925        NaN      Yes  NaN        NaN      NaN        NaN
# 64460       65112        NaN      Yes  NaN        NaN      NaN        NaN
#
#        ConvertedComp        Country CurrencyDesc CurrencySymbol  \
# 64451            NaN         Poland          NaN            NaN
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv' , index_col = 'Column')

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Trans']
# Out:
# QuestionText    Are you transgender?
# Name: Trans, dtype: object

# %%
df[: 15]
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1                     I am a developer by profession      Yes
# 1            2                     I am a developer by profession       No
# 2            3                        I code primarily as a hobby      Yes
# 3            4                     I am a developer by profession      Yes
# 4            5  I used to be a developer by profession, but no...      Yes
# 5            6                     I am a developer by profession       No
# 6            7                     I am a developer by profession      Yes
# 7            8                     I am a developer by profession      Yes
# 8            9                     I am a developer by profession       No
# 9           10                     I am a developer by profession      Yes
# 10          11                     I am a developer by profession      Yes
# ...

# %%
df['MainBranch'][10]

# %%
print(df['MainBranch'][10])

# %%
import csv
reader = csv.DictReader(open('data\survey_results_public.csv'))

result = {}
for row in reader:
    for column, value in row.items():  # consider .iteritems() for Python 2
        result.setdefault(column, []).append(value)
print(result)

# %%
type(df['MainBranch'][10])

# %%
df.MainBranch

# %%
df['Country']

# %%
df.set_index('Respondent' , inplace = True)

# %%
df

# %%
df.index

# %%
df.loc[1 , 'Country']

# %%
high_salary = (df['ConvertedComp'] > 5000 & df['LanguageWorkedWith'].str.contains('python'))

# %%
xd = df[high_salary , 'LanguageWorkedWith']

# %%
xd[:10]

# %%
df.columns

# %%
df.rename(columns = {'ConvertedComp' : 'SalaryUSD'} , inplace = True)

# %%
df['SalaryUSD']

# %%
df.head()

# %%
df['Hobbyist']

# %%
df['Hobbyist'].map({'yes' : True , 'No' : False})

# %%
df['Hobbyist'] = df['Hobbyist'].map({'yes' : True , 'No' : False})

# %%
df.apply(len)

# %%
df[df['Country'].str.len() > 9]

# %%
df.info()

# %%
df.applymap(len)

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'ConvertedComp']].head(50)

# %%
df['ConvertedComp'].nlargest(10)

# %%
df.nsmallest(10, 'ConvertedComp')

# %%
df.nlargest(10,'ConvertedComp')

# %%
df.head()

# %%
df['ConvertedComp'].head(15)

# %%
df['ConvertedComp'].median()

# %%
df.median()

# %%
df.describe()

# %%
df['ConvertedComp'].count()

# %%
df['Hobbyist']

# %%
df['Hobbyist'].value_counts()

# %%
df['Country'].value_counts()

# %%
df['Trans'].value_counts(normalize=True)

# %%
df['Country'].value_counts()

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_grp['ConvertedComp'].median().loc['Germany']

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']

# %%
country_respondent = df['Country'].value_counts()
country_respondent

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python

# %%
python_df = pd.concat([country_respondent, country_uses_python], axis='columns', sort=False)
python_df

# %%
python_df.rename(columns={'Country': 'NumRespondents'}, inplace= True)

# %%
python_df

# %%
python_df['pctknowsPython'] = (python_df['LanguageWorkedWith']/python_df['NumRespondents']) * 100
python_df

# %%
python_df.sort_values(by = 'pctknowsPython' , ascending = False , inplace = True)

# %%
python_df
# Out:
#                                     NumRespondents  LanguageWorkedWith  \
# Micronesia, Federated States of...               1                   1
# Saint Lucia                                      1                   1
# Gabon                                            1                   1
# Montenegro                                      13                   9
# Brunei Darussalam                                3                   2
# Guyana                                           5                   3
# Swaziland                                        7                   4
# Iceland                                         53                  28
# Finland                                        349                 183
# Uganda                                          81                  42
# Timor-Leste                                      2                   1
# Jamaica                                         14                   7
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents        297.000000
# LanguageWorkedWith    132.000000
# pctknowsPython         44.444444
# Name: Japan, dtype: float64

# %%
country_grp['LanguageWorkedWith'].apply(lambda series: series.str.contains('Python').sum()/len(series))
# Out:
# Country
# Afghanistan                                  0.130952
# Albania                                      0.240741
# Algeria                                      0.425532
# Andorra                                      0.230769
# Angola                                       0.111111
# Antigua and Barbuda                          0.000000
# Argentina                                    0.339241
# Armenia                                      0.265625
# Australia                                    0.433775
# Austria                                      0.380334
# Azerbaijan                                   0.220000
# Bahamas                                      0.333333
# Bahrain                                      0.222222
# Bangladesh                                   0.293924
# Barbados                                     0.400000
# Belarus                                      0.310078
# Belgium                                      0.376906
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1     36
# 2      7
# 3      4
# 4      7
# 5     15
# 6      6
# 7      6
# 8     17
# 9      6
# 10     8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 0, '3', '13', '25', '16', '43',
#        '11', '38', '33', nan, '24', '21', '12', '40', '27', '50', '46',
#        '14', '18', '28', '32', '44', '26', '42', '31', '34', '29', '1',
#        '39', '41', '45', 51, '47', '49', '48'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year' , 0, inplace= True)

# %%
df['YearsCode'].replace('More than 50 years' , 51, inplace= True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
# 11                             I am a developer by profession      Yes  23.0
# ...
